# %% [markdown]
# # Install and import needed packages

# %%
# #%%capture
# #!sudo apt-get update
# !apt install ffmpeg
# !apt install xvfb
# !pip3 install pyvirtualdisplay
# !pip install gym[box2d]
# !pip install stable-baselines3[extra]
# !pip install huggingface_sb3
# !pip install pyglet
# !pip install ale-py==0.7.4 # To overcome an issue with gym (https://github.com/DLR-RM/stable-baselines3/issues/875)
# !pip install pygad
# !pip install pickle5
# !pip install cma

# %%
# Import libraries
import gym
import time
import gym
import numpy as np
import torch
import torch.nn as nn
import math
import pyglet
import torchvision
from PIL import Image
import torch.nn.functional as F
import cma
import time
import random
import pickle
from tqdm import tqdm

# %% [markdown]
# # Seeds for reproducibility

# %%
# Set seeds
np.random.seed(12345)
random.seed(12345)
torch.manual_seed(12345)
torch.cuda.manual_seed_all(12345)
torch.backends.cudnn.deterministic = True  # Note that this Deterministic mode can have a performance impact
torch.backends.cudnn.benchmark = False
# Out:
# /home/gianmarco/anaconda3/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# # Utils functions

# %%
# Define utils to count the parameters in a model 
def get_n_params(model):
    pp=0
    for p in list(model.parameters()):
        nn=1
        for s in list(p.size()):
            nn = nn*s
        pp += nn
    return pp

# %%
# Define utils to store the model state dict. Needed during CMA
def store_state_dict(model):
    state_dict={}
    for param_tensor in model.state_dict():
        shape=model.state_dict()[param_tensor].shape
        state_dict[param_tensor]= {"size":np.prod([i for i in shape]),"shape":tuple([i for i in shape])}
    return state_dict

# %%
# Define utils to load model state dict. Needed during CMA
def load_state_dict(model, params, old_dict):
    new_dict    = {}
    done_params = 0
    
    for param_tensor in old_dict:
        size                   = old_dict[param_tensor]["size"]
        shape                  = old_dict[param_tensor]["shape"]
        new_dict[param_tensor] = torch.reshape(torch.tensor(params[done_params:done_params+size]),shape)
        done_params           += size
    
    model.load_state_dict(new_dict)
    return model

# %% [markdown]
# # Training Utils functions

# %%
# Define preprocessing util to graysccale and normalize pixel values
def state_processer(image):
    PIL_img = Image.fromarray(np.uint8(image)).convert('L')
    torch_img  = torch.tensor(np.array(PIL_img),dtype=torch.float).unsqueeze(-1)
    return torch_img/255

# %%
# Define util to stack temporal observations
def cycle_observation(observations,new_observation):
    observations[:,:,0]=observations[:,:,1]
    observations[:,:,1]=observations[:,:,2]
    observations[:,:,2]=new_observation[:,:,0]
    return observations

# %%
def fitness(gamma):
    global model, autoencoder

    observation = state_processer(env.reset())
    ob_tensor   = torch.cat((observation,observation,observation),dim=-1)
    
    sum_reward  = 0
    done        = False
    step        = 0
    
    while (not done) and (sum_reward < 1000):
        step                                += 1
        actual_gamma                         = gamma**(step)
        action, top_patches                  = model(ob_tensor,autoencoder)
        observation_next, reward, done, info = env.step(action)
        observation_next                     = state_processer(observation_next)
        ob_tensor                            = cycle_observation(ob_tensor,observation_next)
        sum_reward                          += actual_gamma*reward         

    return -sum_reward

# %%
def train(es,env,model,max_generations,autoencoder,old_dict,gamma):
        
    fitness_values    = []
    absolute_best_fit = 10000
    gen               = 1
    while not es.stop():
        if gen > max_generations:
            break
        start_time       = time.time()
        solutions        = es.ask()
        current_gen_fit  = []
        
        for sol_id, params in enumerate(solutions): 
            model            = load_state_dict(model, params, old_dict)
            value            = fitness(gamma)
            current_gen_fit.append(value)
            
            if value < absolute_best_fit:
                best_model        = solutions[sol_id]
                absolute_best_fit = value


        fitness_values.append(current_gen_fit)
        end_time   = time.time()
        best_fit   = np.min(current_gen_fit)
        print("Generation {} executed in {} s. Best fitness value: {}".format(gen,round(end_time-start_time,2),round(best_fit,4)))
        es.tell(solutions, current_gen_fit)
        gen+=1
    
    
    return fitness_values, best_model

# %% [markdown]
# # Models

# %%
# Define simple autoencoder class
class Autoencoder(nn.Module):
    def __init__(self):
        super(Autoencoder, self).__init__()
        self.encoder = nn.Sequential( 
            nn.Conv2d(3, 32, 3, stride=1),
            nn.ReLU(),
            nn.Conv2d(32, 64, 3, stride=1),
            nn.ReLU(),
            nn.Conv2d(64, 128, 3, stride=1),
            nn.ReLU(),
            nn.Conv2d(128, 256, 2)
        )

        self.decoder = nn.Sequential(
            nn.ConvTranspose2d(256, 128, 2),
            nn.ReLU(),
            nn.ConvTranspose2d(128, 64, 3, stride=1),
            nn.ReLU(),
            nn.ConvTranspose2d(64, 32, 3, stride=1),
            nn.ReLU(),
            nn.ConvTranspose2d(32, 3, 3, stride=1),         
            nn.Sigmoid()
        )

    def forward(self, x):
        x = x.permute(0,3,1,2)
        code = self.encoder(x)
        reconstruction = self.decoder(code)

        return code, reconstruction

# %%
class Attention_module(nn.Module):
    def __init__(self,in_dimension,out_dimension):
        super(Attention_module, self).__init__()
      
        self.out_dimension  = out_dimension
        self.in_dimension   = in_dimension  
        self.attention1     = nn.Linear(self.in_dimension,self.out_dimension)
        self.attention2     = nn.Linear(self.in_dimension,self.out_dimension)

        
    def forward(self, x):
        # Compute query projection
        q                 = self.attention1(x)
        # Compute key projection
        k                 = self.attention2(x)
        scaled_mm         = (q @ k.T)/math.sqrt(self.in_dimension)

        scaled_mm         = (q @ k.T)/math.sqrt(self.in_dimension)
        # Compute attention scores
        attention_scores  = torch.nn.functional.softmax(scaled_mm, dim=1)
      
        return attention_scores 

class Patcher_module(nn.Module):
    def __init__(self,stride,window,channels):
        super(Patcher_module, self).__init__()
      
        self.stride   = stride
        self.window   = window
        self.channels = channels

        
    def forward(self, x):
        # Extract overlapping patches over the inputted images
        patches           = x.unfold(0, self.window, self.stride).unfold(1,self.window,self.stride).reshape((-1, self.channels,self.window,self.window)).permute(0,2,3,1)
        n_patches         = patches.shape[0]
        flattened_patches = patches.reshape((n_patches,-1))
        
        # Return flattened and non-flattened patches
        return patches,flattened_patches

class Slicer_module(nn.Module):
    def __init__(self,K,):
        super(Slicer_module, self).__init__()
      
        self.K = K
        
    def forward(self, x):
        # Perform row-wise sum of attention scores
        score_sums                    = torch.sum(x,dim=0)
        sorted_scores,indexes         = torch.sort(score_sums,descending=True)
        sliced_scores,sliced_indexes  = sorted_scores[:self.K],indexes[:self.K]
        
        # Return top-K best scores and corresponding patch indexes
        return sliced_scores,sliced_indexes

class Feature_extractor_module(nn.Module):
    def __init__(self,FEAT_EXTRACT,stride,window):
        super(Feature_extractor_module,self).__init__()
        
        self.stride          = stride
        self.window          = window
        self.feat_extract    = FEAT_EXTRACTOR

    
        if self.feat_extract=="CONV":
            self.convolutions = nn.Sequential(
                nn.Conv2d(in_channels=3, out_channels=10, kernel_size=3, stride=1 ),
                nn.ReLU(),
                nn.Conv2d(in_channels=10, out_channels=10, kernel_size=3, stride=1 ),
                nn.ReLU(),
                nn.Conv2d(in_channels=10, out_channels=10, kernel_size=3, stride=1 ),
                nn.ReLU(),
                nn.Conv2d(in_channels=10, out_channels=2, kernel_size=2, stride=1)
            )

    def forward(self,top_patches,top_idxs,n,top_scores):
            
        if self.feat_extract=="LOC":
        # Compute top-patches coordinates given their indexes
            x = torch.tensor([[idx//n*self.stride+self.window/2,(idx-(idx//n)*n)*self.stride+self.window/2] for i,idx in enumerate(top_idxs.tolist())])
            
        if self.feat_extract=="CONV":
            # Compute top-patches features via convolutions
            x = self.convolutions(top_patches.permute(0,3,1,2))
     
            
        feats = x.flatten().unsqueeze(0)
              
        return feats
            
class Controller_module(nn.Module):
    def __init__(self,in_dim,out_dim,CONTINUOUS):
        super(Controller_module, self).__init__()
        self.linear=nn.Linear(in_dim,out_dim)
        self.continuous=CONTINUOUS  

    def forward(self, x):
        logits                    = self.linear(x)
        # If the played game is continuous, the returned action
        # is an array of size 3. 
        # 1st element correspond to steer and is in [-1,1].
        # 2nd element correspond to brake and is in [0, 1].
        # 3rd element correspond to gas and is in [0, 1].
        if self.continuous:
            steer                     = logits[:,:1]
            brake_gas                 = logits[:,1:]
            tuple_of_activated_parts  = (
                                      torch.tanh(steer),
                                      torch.sigmoid(brake_gas)
                                      )
            action                    = torch.cat(tuple_of_activated_parts, dim=1).squeeze().numpy()
        
        # If the played game is discrete, action is the classical argmax of logits
        else:
          if logits.shape[0]==1:
            action=np.array(torch.argmax(logits).item())
          else:
            action=np.array(torch.mode(torch.argmax(logits,dim=1))[0].item())
        
        return action

class Agent(nn.Module):
    def __init__(self,obs_space,stride,window,channels,
                 attention_out_dim,K,lstm_hidden_dim,
                 eps,CONTINUOUS,FEAT_EXTRACTOR):
        
        super(Agent, self).__init__()
        if CONTINUOUS:
            self.action_class     = 3
        else:
            self.action_class     = 5
        self.obs_space            = obs_space
        self.stride               = stride
        self.window               = window
        self.channels             = channels
        self.attention_out_dim    = attention_out_dim
        self.attention_in_dim     = window*window*channels
        self.K                    = K
        self.lstm_hidden_dim      = lstm_hidden_dim
        self.continuous           = CONTINUOUS
        self.eps                  = eps
        self.grayscaler           = torchvision.transforms.Grayscale(num_output_channels=1)

        self.attention            = Attention_module(self.attention_in_dim,self.attention_out_dim)
        self.patch_extractor      = Patcher_module(self.stride,self.window,self.channels)
        self.slicer               = Slicer_module(self.K)
        self.feat_extractor       = Feature_extractor_module(FEAT_EXTRACTOR, stride, window)
        self.controller           = Controller_module(self.lstm_hidden_dim,self.action_class,CONTINUOUS)
        if FEAT_EXTRACTOR!="AE":
          self.rnn                  = nn.LSTM(self.K*2, self.lstm_hidden_dim,batch_first=True)   
        
    def forward(self, x,autoencoder=None):
        patches,flat_patches     = self.patch_extractor(x)
        # Extract sqrt value of the number of extracted patches (for location extraction purposes)
        n                        = math.sqrt(flat_patches.shape[0])
        attention_scores         = self.attention(flat_patches)
        top_scores,top_idxs      = self.slicer(attention_scores)
        top_patches              = torch.index_select(patches, 0, top_idxs)
        
        if autoencoder:
            feats,reconstruction = autoencoder(top_patches)
            feats                = feats.squeeze()
        
        else:
            feats                = self.feat_extractor(top_patches,top_idxs,n,top_scores)
            feats,_              = self.rnn(feats)
           
        out                      = self.controller(feats)
        rand                     = torch.rand(1).item()
        # Balance among experience and discovery: 
        # the action will be random with probability eps
        if rand<self.eps:
            if self.continuous:
                out    = np.random.rand(self.action_class,)
                out[0] = (out[0]-0.5)*2
            else:
                out    = torch.randint(self.action_class,(1,)).item()
        return out, top_patches
# Out:
# /home/gianmarco/anaconda3/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# # Training

# %% [markdown]
# ## Top-patch location feature extractor

# %%
torch.set_grad_enabled(False)

observation_space_size = 96
stride                 = 4
window                 = 8
channels               = 3
attention_out_dim      = 4
K                      = 10
lstm_hidden_dim        = 16
eps                    = 0.05
CONTINUOUS             = False
                       ###### Choose between "LOC" and "CONV"
FEAT_EXTRACTOR         = "LOC"

model=Agent(observation_space_size,stride,window,
            channels,attention_out_dim,K,lstm_hidden_dim,
            eps,CONTINUOUS,FEAT_EXTRACTOR)
model
# Out:
# Agent(
#   (grayscaler): Grayscale(num_output_channels=1)
#   (attention): Attention_module(
#     (attention1): Linear(in_features=192, out_features=4, bias=True)
#     (attention2): Linear(in_features=192, out_features=4, bias=True)
#   )
#   (patch_extractor): Patcher_module()
#   (slicer): Slicer_module()
#   (feat_extractor): Feature_extractor_module()
#   (controller): Controller_module(
#     (linear): Linear(in_features=16, out_features=5, bias=True)
#   )
#   (rnn): LSTM(20, 16, batch_first=True)
# )

# %%
print("Model's state_dict:")
old_dict=store_state_dict(model)
old_dict
# Out:
# Model's state_dict:
# {'attention.attention1.weight': {'size': 768, 'shape': (4, 192)},
#  'attention.attention1.bias': {'size': 4, 'shape': (4,)},
#  'attention.attention2.weight': {'size': 768, 'shape': (4, 192)},
#  'attention.attention2.bias': {'size': 4, 'shape': (4,)},
#  'controller.linear.weight': {'size': 80, 'shape': (5, 16)},
#  'controller.linear.bias': {'size': 5, 'shape': (5,)},
#  'rnn.weight_ih_l0': {'size': 1280, 'shape': (64, 20)},
#  'rnn.weight_hh_l0': {'size': 1024, 'shape': (64, 16)},
#  'rnn.bias_ih_l0': {'size': 64, 'shape': (64,)},
#  'rnn.bias_hh_l0': {'size': 64, 'shape': (64,)}}

# %%
n=get_n_params(model)
print("Model contains {} parameters.".format(n))
# Out:
# Model contains 4061 parameters.

# %%
es                = cma.CMAEvolutionStrategy(n * [0], 0.01,{"seed":12345})
env               = gym.make("CarRacing-v2",continuous=CONTINUOUS)
max_generation    = 600
gamma             = 0.999
autoencoder       = None
# autoencoder       = Autoencoder()

fitness_values_LOC, best_model_LOC  = train(es,env,model,max_generation,autoencoder,old_dict,gamma)
# Out:
# (14_w,28)-aCMA-ES (mu_w=8.1,w_1=21%) in dimension 4061 (seed=12345, Thu Sep  8 12:53:39 2022)
# Generation 1 executed in 278.38 s. Best fitness value: 14.8152
# Generation 2 executed in 244.65 s. Best fitness value: -40.3449
# Generation 3 executed in 208.16 s. Best fitness value: -63.5775
# Generation 4 executed in 214.13 s. Best fitness value: -54.0353
# Generation 5 executed in 219.37 s. Best fitness value: -42.6086
# Generation 6 executed in 205.9 s. Best fitness value: -24.676
# Generation 7 executed in 197.65 s. Best fitness value: -52.5358
# Generation 8 executed in 213.34 s. Best fitness value: -120.0463
# Generation 9 executed in 191.18 s. Best fitness value: -50.4142
# Generation 10 executed in 189.32 s. Best fitness value: -48.6149
# Generation 11 executed in 160.51 s. Best fitness value: -46.8494
# Generation 12 executed in 245.84 s. Best fitness value: -38.0001
# Generation 13 executed in 202.89 s. Best fitness value: -14.2416
# Generation 14 executed in 182.47 s. Best fitness value: -53.2481
# Generation 15 executed in 212.84 s. Best fitness value: -48.9174
# Generation 16 executed in 212.48 s. Best fitness value: -39.1835
# Generation 17 executed in 153.85 s. Best fitness value: -60.1157
# Generation 18 executed in 200.76 s. Best fitness value: -47.9173
# Generation 19 executed in 207.03 s. Best fitness value: -44.8959
# Generation 20 executed in 187.22 s. Best fitness value: -54.3647
# Generation 21 executed in 176.39 s. Best fitness value: -50.282
# Generation 22 executed in 142.05 s. Best fitness value: -31.7518
# Generation 23 executed in 156.61 s. Best fitness value: -20.9512
# Generation 24 executed in 151.55 s. Best fitness value: -31.5064
# Generation 25 executed in 167.57 s. Best fitness value: -51.756
# Generation 26 executed in 120.69 s. Best fitness value: -70.1818
# Generation 27 executed in 171.93 s. Best fitness value: -67.8824
# Generation 28 executed in 200.39 s. Best fitness value: -70.7847
# Generation 29 executed in 182.35 s. Best fitness value: -53.4074
# Generation 30 executed in 148.29 s. Best fitness value: -55.0019
# Generation 31 executed in 185.56 s. Best fitness value: -54.1765
# Generation 32 executed in 177.0 s. Best fitness value: -52.715
# Generation 33 executed in 208.78 s. Best fitness value: -62.4204
# Generation 34 executed in 209.36 s. Best fitness value: -79.6003
# Generation 35 executed in 180.12 s. Best fitness value: -63.6163
# Generation 36 executed in 189.41 s. Best fitness value: -69.504
# Generation 37 executed in 175.77 s. Best fitness value: -62.8229
# Generation 38 executed in 191.33 s. Best fitness value: -39.901
# Generation 39 executed in 274.77 s. Best fitness value: -96.5907
# Generation 40 executed in 277.52 s. Best fitness value: -57.0116
# Generation 41 executed in 263.16 s. Best fitness value: -63.3935
# Generation 42 executed in 301.76 s. Best fitness value: -104.8285
# Generation 43 executed in 287.52 s. Best fitness value: -139.2332
# Generation 44 executed in 285.0 s. Best fitness value: -125.2063
# Generation 45 executed in 259.91 s. Best fitness value: -35.7187
# Generation 46 executed in 274.55 s. Best fitness value: -88.5574
# Generation 47 executed in 256.57 s. Best fitness value: -61.0237
# Generation 48 executed in 238.52 s. Best fitness value: -49.3054
# Generation 49 executed in 236.18 s. Best fitness value: -87.442
# Generation 50 executed in 275.24 s. Best fitness value: -82.3477
# Generation 51 executed in 247.81 s. Best fitness value: -75.5091
# Generation 52 executed in 236.01 s. Best fitness value: -183.6115
# Generation 53 executed in 300.24 s. Best fitness value: -158.6074
# Generation 54 executed in 219.3 s. Best fitness value: -77.8851
# Generation 55 executed in 256.27 s. Best fitness value: -156.5731
# Generation 56 executed in 273.68 s. Best fitness value: -96.1278
# Generation 57 executed in 239.07 s. Best fitness value: -88.5008
# Generation 58 executed in 233.05 s. Best fitness value: -101.1907
# Generation 59 executed in 213.83 s. Best fitness value: -134.1951
# Generation 60 executed in 233.61 s. Best fitness value: -215.6258
# Generation 61 executed in 227.16 s. Best fitness value: -257.8461
# Generation 62 executed in 249.56 s. Best fitness value: -303.5535
# Generation 63 executed in 275.59 s. Best fitness value: -120.1417
# Generation 64 executed in 277.45 s. Best fitness value: -132.0507
# Generation 65 executed in 383.78 s. Best fitness value: -262.1913
# Generation 66 executed in 340.7 s. Best fitness value: -266.738
# Generation 67 executed in 310.13 s. Best fitness value: -198.934
# Generation 68 executed in 318.56 s. Best fitness value: -292.9062
# Generation 69 executed in 259.9 s. Best fitness value: -159.1606
# Generation 70 executed in 322.32 s. Best fitness value: -252.9016
# Generation 71 executed in 284.07 s. Best fitness value: -181.8453
# Generation 72 executed in 302.99 s. Best fitness value: -181.3019
# Generation 73 executed in 345.94 s. Best fitness value: -283.1948
# Generation 74 executed in 287.88 s. Best fitness value: -326.2302
# Generation 75 executed in 224.61 s. Best fitness value: -246.7909
# Generation 76 executed in 228.74 s. Best fitness value: -254.0944
# Generation 77 executed in 272.29 s. Best fitness value: -257.6122
# Generation 78 executed in 285.26 s. Best fitness value: -212.6685
# Generation 79 executed in 252.27 s. Best fitness value: -245.2958
# Generation 80 executed in 248.04 s. Best fitness value: -246.6876
# Generation 81 executed in 244.23 s. Best fitness value: -261.6411
# Generation 82 executed in 250.96 s. Best fitness value: -157.9839
# Generation 83 executed in 281.97 s. Best fitness value: -244.7054
# Generation 84 executed in 261.58 s. Best fitness value: -300.6224
# Generation 85 executed in 294.3 s. Best fitness value: -172.2393
# Generation 86 executed in 288.77 s. Best fitness value: -280.6002
# Generation 87 executed in 274.94 s. Best fitness value: -295.2716
# Generation 88 executed in 301.89 s. Best fitness value: -319.8745
# Generation 89 executed in 283.27 s. Best fitness value: -366.7925
# Generation 90 executed in 276.53 s. Best fitness value: -226.436
# Generation 91 executed in 288.62 s. Best fitness value: -306.2909
# Generation 92 executed in 292.17 s. Best fitness value: -226.2005
# Generation 93 executed in 289.49 s. Best fitness value: -233.9144
# Generation 94 executed in 278.61 s. Best fitness value: -155.7107
# Generation 95 executed in 276.24 s. Best fitness value: -330.6198
# Generation 96 executed in 299.7 s. Best fitness value: -225.6154
# Generation 97 executed in 273.63 s. Best fitness value: -210.3599
# Generation 98 executed in 314.98 s. Best fitness value: -320.5964
# Generation 99 executed in 309.11 s. Best fitness value: -272.3195
# Generation 100 executed in 291.34 s. Best fitness value: -288.7088
# Generation 101 executed in 280.01 s. Best fitness value: -231.7659
# Generation 102 executed in 290.63 s. Best fitness value: -257.4732
# Generation 103 executed in 277.83 s. Best fitness value: -253.4679
# Generation 104 executed in 222.3 s. Best fitness value: -340.5027
# Generation 105 executed in 240.9 s. Best fitness value: -319.1593
# Generation 106 executed in 254.13 s. Best fitness value: -446.1609
# Generation 107 executed in 261.53 s. Best fitness value: -389.9891
# Generation 108 executed in 250.41 s. Best fitness value: -388.3812
# Generation 109 executed in 250.83 s. Best fitness value: -261.7446
# Generation 110 executed in 255.1 s. Best fitness value: -269.1247
# Generation 111 executed in 281.88 s. Best fitness value: -269.2489
# Generation 112 executed in 324.44 s. Best fitness value: -293.6465
# Generation 113 executed in 370.09 s. Best fitness value: -356.002
# Generation 114 executed in 303.87 s. Best fitness value: -289.4336
# Generation 115 executed in 315.83 s. Best fitness value: -229.9381
# Generation 116 executed in 301.01 s. Best fitness value: -274.4791
# Generation 117 executed in 314.33 s. Best fitness value: -385.5219
# Generation 118 executed in 292.97 s. Best fitness value: -273.5896
# Generation 119 executed in 279.79 s. Best fitness value: -265.7093
# Generation 120 executed in 303.29 s. Best fitness value: -320.736
# Generation 121 executed in 260.95 s. Best fitness value: -393.8182
# Generation 122 executed in 275.91 s. Best fitness value: -278.7081
# Generation 123 executed in 291.15 s. Best fitness value: -418.6211
# Generation 124 executed in 279.17 s. Best fitness value: -292.0349
# Generation 125 executed in 243.02 s. Best fitness value: -287.4617
# Generation 126 executed in 242.36 s. Best fitness value: -239.1224
# Generation 127 executed in 253.99 s. Best fitness value: -322.1835
# Generation 128 executed in 232.49 s. Best fitness value: -350.2849
# Generation 129 executed in 264.88 s. Best fitness value: -318.6279
# Generation 130 executed in 265.39 s. Best fitness value: -238.5451
# Generation 131 executed in 247.86 s. Best fitness value: -278.1008
# Generation 132 executed in 256.11 s. Best fitness value: -276.3619
# Generation 133 executed in 258.93 s. Best fitness value: -367.093
# Generation 134 executed in 262.93 s. Best fitness value: -294.4181
# Generation 135 executed in 283.75 s. Best fitness value: -334.3201
# Generation 136 executed in 287.69 s. Best fitness value: -308.1792
# Generation 137 executed in 254.58 s. Best fitness value: -288.2731
# Generation 138 executed in 342.79 s. Best fitness value: -367.4766
# Generation 139 executed in 315.13 s. Best fitness value: -369.8698
# Generation 140 executed in 308.38 s. Best fitness value: -394.9691
# Generation 141 executed in 302.23 s. Best fitness value: -330.0237
# Generation 142 executed in 309.36 s. Best fitness value: -411.0456
# Generation 143 executed in 247.84 s. Best fitness value: -319.4939
# Generation 144 executed in 281.18 s. Best fitness value: -346.1793
# Generation 145 executed in 279.74 s. Best fitness value: -389.5242
# Generation 146 executed in 286.95 s. Best fitness value: -299.0708
# Generation 147 executed in 303.82 s. Best fitness value: -331.96
# Generation 148 executed in 314.47 s. Best fitness value: -340.7982
# Generation 149 executed in 319.32 s. Best fitness value: -377.5672
# Generation 150 executed in 316.1 s. Best fitness value: -287.5634
# Generation 151 executed in 309.28 s. Best fitness value: -357.3408
# Generation 152 executed in 326.66 s. Best fitness value: -321.2453
# Generation 153 executed in 309.02 s. Best fitness value: -340.0439
# Generation 154 executed in 312.17 s. Best fitness value: -330.7223
# Generation 155 executed in 296.11 s. Best fitness value: -348.611
# Generation 156 executed in 287.27 s. Best fitness value: -343.8597
# Generation 157 executed in 304.89 s. Best fitness value: -337.4464
# Generation 158 executed in 251.8 s. Best fitness value: -388.5984
# Generation 159 executed in 296.65 s. Best fitness value: -293.8764
# Generation 160 executed in 301.15 s. Best fitness value: -374.8169
# Generation 161 executed in 303.33 s. Best fitness value: -458.7136
# Generation 162 executed in 302.27 s. Best fitness value: -383.412
# Generation 163 executed in 295.71 s. Best fitness value: -368.5491
# Generation 164 executed in 318.53 s. Best fitness value: -322.5832
# Generation 165 executed in 297.91 s. Best fitness value: -340.3327
# Generation 166 executed in 310.48 s. Best fitness value: -273.0016
# Generation 167 executed in 330.9 s. Best fitness value: -441.3337
# Generation 168 executed in 308.21 s. Best fitness value: -290.3962
# Generation 169 executed in 335.79 s. Best fitness value: -376.6181
# Generation 170 executed in 313.65 s. Best fitness value: -328.3634
# Generation 171 executed in 316.53 s. Best fitness value: -511.589
# Generation 172 executed in 296.7 s. Best fitness value: -400.8157
# Generation 173 executed in 309.25 s. Best fitness value: -379.5047
# Generation 174 executed in 329.27 s. Best fitness value: -312.5651
# Generation 175 executed in 273.92 s. Best fitness value: -312.269
# Generation 176 executed in 264.28 s. Best fitness value: -359.9174
# Generation 177 executed in 284.27 s. Best fitness value: -354.324
# Generation 178 executed in 240.39 s. Best fitness value: -312.3686
# Generation 179 executed in 268.93 s. Best fitness value: -388.9701
# Generation 180 executed in 297.44 s. Best fitness value: -376.903
# Generation 181 executed in 286.58 s. Best fitness value: -374.4207
# Generation 182 executed in 292.64 s. Best fitness value: -393.3522
# Generation 183 executed in 287.98 s. Best fitness value: -333.1794
# Generation 184 executed in 278.29 s. Best fitness value: -363.858
# Generation 185 executed in 287.18 s. Best fitness value: -255.5264
# Generation 186 executed in 254.91 s. Best fitness value: -383.143
# Generation 187 executed in 275.87 s. Best fitness value: -378.3653
# Generation 188 executed in 232.11 s. Best fitness value: -306.9929
# Generation 189 executed in 252.6 s. Best fitness value: -391.3478
# Generation 190 executed in 266.56 s. Best fitness value: -266.6167
# Generation 191 executed in 274.26 s. Best fitness value: -318.8002
# Generation 192 executed in 299.6 s. Best fitness value: -349.4921
# Generation 193 executed in 286.28 s. Best fitness value: -326.8923
# Generation 194 executed in 281.85 s. Best fitness value: -306.5911
# Generation 195 executed in 286.51 s. Best fitness value: -288.977
# Generation 196 executed in 267.83 s. Best fitness value: -316.3541
# Generation 197 executed in 291.71 s. Best fitness value: -284.9261
# Generation 198 executed in 252.81 s. Best fitness value: -390.3109
# Generation 199 executed in 270.32 s. Best fitness value: -320.7467
# Generation 200 executed in 276.75 s. Best fitness value: -364.9177
# Generation 201 executed in 294.25 s. Best fitness value: -382.4855
# Generation 202 executed in 283.72 s. Best fitness value: -363.8311
# Generation 203 executed in 248.89 s. Best fitness value: -320.3804
# Generation 204 executed in 262.56 s. Best fitness value: -326.3491
# Generation 205 executed in 287.37 s. Best fitness value: -417.6037
# Generation 206 executed in 272.33 s. Best fitness value: -387.2512
# Generation 207 executed in 262.78 s. Best fitness value: -411.1735
# Generation 208 executed in 250.45 s. Best fitness value: -371.5781
# Generation 209 executed in 276.06 s. Best fitness value: -314.1871
# Generation 210 executed in 248.97 s. Best fitness value: -410.9416
# Generation 211 executed in 266.94 s. Best fitness value: -300.8257
# Generation 212 executed in 270.01 s. Best fitness value: -342.5329
# Generation 213 executed in 275.25 s. Best fitness value: -358.4168
# Generation 214 executed in 289.86 s. Best fitness value: -379.7768
# Generation 215 executed in 243.01 s. Best fitness value: -304.4728
# Generation 216 executed in 283.25 s. Best fitness value: -347.5788
# Generation 217 executed in 275.36 s. Best fitness value: -332.3456
# Generation 218 executed in 260.58 s. Best fitness value: -303.5092
# Generation 219 executed in 273.32 s. Best fitness value: -398.2892
# Generation 220 executed in 281.65 s. Best fitness value: -389.9811
# Generation 221 executed in 266.74 s. Best fitness value: -354.4275
# Generation 222 executed in 266.66 s. Best fitness value: -300.6555
# Generation 223 executed in 277.86 s. Best fitness value: -389.1833
# Generation 224 executed in 271.8 s. Best fitness value: -389.4465
# Generation 225 executed in 312.14 s. Best fitness value: -405.777
# Generation 226 executed in 294.82 s. Best fitness value: -412.1813
# Generation 227 executed in 283.03 s. Best fitness value: -312.9102
# Generation 228 executed in 290.97 s. Best fitness value: -383.4697
# Generation 229 executed in 283.05 s. Best fitness value: -346.2406
# Generation 230 executed in 289.77 s. Best fitness value: -360.4134
# Generation 231 executed in 296.81 s. Best fitness value: -388.6082
# Generation 232 executed in 278.63 s. Best fitness value: -394.5254
# Generation 233 executed in 301.99 s. Best fitness value: -346.6158
# Generation 234 executed in 295.28 s. Best fitness value: -430.7354
# Generation 235 executed in 288.46 s. Best fitness value: -404.1772
# Generation 236 executed in 293.12 s. Best fitness value: -464.0202
# Generation 237 executed in 290.41 s. Best fitness value: -389.1274
# Generation 238 executed in 304.69 s. Best fitness value: -390.3874
# Generation 239 executed in 302.1 s. Best fitness value: -380.1784
# Generation 240 executed in 288.5 s. Best fitness value: -437.0531
# Generation 241 executed in 304.1 s. Best fitness value: -425.0136
# Generation 242 executed in 262.44 s. Best fitness value: -362.8331
# Generation 243 executed in 245.24 s. Best fitness value: -404.4638
# Generation 244 executed in 259.87 s. Best fitness value: -424.9837
# Generation 245 executed in 276.3 s. Best fitness value: -499.6401
# Generation 246 executed in 299.92 s. Best fitness value: -394.4095
# Generation 247 executed in 306.69 s. Best fitness value: -403.5224
# Generation 248 executed in 302.05 s. Best fitness value: -431.708
# Generation 249 executed in 303.02 s. Best fitness value: -454.0263
# Generation 250 executed in 297.69 s. Best fitness value: -467.0483
# Generation 251 executed in 296.46 s. Best fitness value: -455.1235
# Generation 252 executed in 290.94 s. Best fitness value: -439.2192
# Generation 253 executed in 315.17 s. Best fitness value: -383.2074
# Generation 254 executed in 288.37 s. Best fitness value: -454.0446
# Generation 255 executed in 282.26 s. Best fitness value: -348.6179
# Generation 256 executed in 302.53 s. Best fitness value: -314.491
# Generation 257 executed in 294.02 s. Best fitness value: -396.6058
# Generation 258 executed in 300.19 s. Best fitness value: -416.9039
# Generation 259 executed in 286.43 s. Best fitness value: -420.5697
# Generation 260 executed in 280.77 s. Best fitness value: -478.165
# Generation 261 executed in 290.34 s. Best fitness value: -474.0211
# Generation 262 executed in 309.01 s. Best fitness value: -309.21
# Generation 263 executed in 285.06 s. Best fitness value: -431.7011
# Generation 264 executed in 307.35 s. Best fitness value: -453.334
# Generation 265 executed in 283.07 s. Best fitness value: -392.4149
# Generation 266 executed in 287.22 s. Best fitness value: -369.5338
# Generation 267 executed in 301.92 s. Best fitness value: -398.0788
# Generation 268 executed in 311.5 s. Best fitness value: -484.7261
# Generation 269 executed in 302.49 s. Best fitness value: -410.8469
# Generation 270 executed in 318.94 s. Best fitness value: -476.1508
# Generation 271 executed in 314.47 s. Best fitness value: -411.7114
# Generation 272 executed in 313.02 s. Best fitness value: -366.5808
# Generation 273 executed in 304.56 s. Best fitness value: -398.9742
# Generation 274 executed in 314.57 s. Best fitness value: -412.5291
# Generation 275 executed in 314.17 s. Best fitness value: -412.8615
# Generation 276 executed in 315.5 s. Best fitness value: -434.7285
# Generation 277 executed in 311.46 s. Best fitness value: -467.1764
# Generation 278 executed in 309.84 s. Best fitness value: -406.5549
# Generation 279 executed in 314.0 s. Best fitness value: -479.2968
# Generation 280 executed in 317.81 s. Best fitness value: -431.6362
# Generation 281 executed in 304.22 s. Best fitness value: -404.657
# Generation 282 executed in 306.5 s. Best fitness value: -490.1978
# Generation 283 executed in 313.24 s. Best fitness value: -459.7909
# Generation 284 executed in 309.77 s. Best fitness value: -374.8082
# Generation 285 executed in 335.32 s. Best fitness value: -393.4921
# Generation 286 executed in 328.0 s. Best fitness value: -508.4453
# Generation 287 executed in 333.97 s. Best fitness value: -403.5632
# Generation 288 executed in 328.02 s. Best fitness value: -490.1169
# Generation 289 executed in 327.29 s. Best fitness value: -378.7307
# Generation 290 executed in 312.42 s. Best fitness value: -552.3977
# Generation 291 executed in 306.24 s. Best fitness value: -528.9749
# Generation 292 executed in 294.62 s. Best fitness value: -496.6813
# Generation 293 executed in 291.75 s. Best fitness value: -502.7736
# Generation 294 executed in 291.45 s. Best fitness value: -528.7588
# Generation 295 executed in 290.2 s. Best fitness value: -494.819
# Generation 296 executed in 285.66 s. Best fitness value: -464.0028
# Generation 297 executed in 284.75 s. Best fitness value: -507.0627
# Generation 298 executed in 279.8 s. Best fitness value: -473.7999
# Generation 299 executed in 306.63 s. Best fitness value: -477.7706
# Generation 300 executed in 321.91 s. Best fitness value: -468.8309
# Generation 301 executed in 312.68 s. Best fitness value: -428.2666
# Generation 302 executed in 324.18 s. Best fitness value: -456.8925
# Generation 303 executed in 304.23 s. Best fitness value: -527.2416
# Generation 304 executed in 306.14 s. Best fitness value: -421.1121
# Generation 305 executed in 323.89 s. Best fitness value: -471.5401
# Generation 306 executed in 318.13 s. Best fitness value: -551.9591
# Generation 307 executed in 294.16 s. Best fitness value: -566.894
# Generation 308 executed in 301.09 s. Best fitness value: -523.6107
# Generation 309 executed in 324.66 s. Best fitness value: -570.6765
# Generation 310 executed in 325.45 s. Best fitness value: -499.0687
# Generation 311 executed in 326.75 s. Best fitness value: -524.3525
# Generation 312 executed in 280.24 s. Best fitness value: -527.411
# Generation 313 executed in 278.43 s. Best fitness value: -481.9888
# Generation 314 executed in 277.17 s. Best fitness value: -506.3241
# Generation 315 executed in 279.54 s. Best fitness value: -486.2923
# Generation 316 executed in 275.2 s. Best fitness value: -502.4138
# Generation 317 executed in 285.83 s. Best fitness value: -513.2315
# Generation 318 executed in 296.7 s. Best fitness value: -530.5327
# Generation 319 executed in 292.54 s. Best fitness value: -500.3499
# Generation 320 executed in 284.11 s. Best fitness value: -482.2397
# Generation 321 executed in 289.11 s. Best fitness value: -489.6926
# Generation 322 executed in 315.75 s. Best fitness value: -523.7323
# Generation 323 executed in 284.79 s. Best fitness value: -490.9217
# Generation 324 executed in 297.28 s. Best fitness value: -519.5645
# Generation 325 executed in 346.01 s. Best fitness value: -515.9481
# Generation 326 executed in 334.15 s. Best fitness value: -524.3674
# Generation 327 executed in 307.57 s. Best fitness value: -496.2859
# Generation 328 executed in 297.47 s. Best fitness value: -549.3797
# Generation 329 executed in 280.78 s. Best fitness value: -494.4093
# Generation 330 executed in 292.9 s. Best fitness value: -506.0079
# Generation 331 executed in 279.96 s. Best fitness value: -524.8403
# Generation 332 executed in 289.34 s. Best fitness value: -493.2975
# Generation 333 executed in 291.82 s. Best fitness value: -537.9174
# Generation 334 executed in 301.77 s. Best fitness value: -510.1718
# Generation 335 executed in 291.92 s. Best fitness value: -508.9862
# Generation 336 executed in 285.84 s. Best fitness value: -540.2112
# Generation 337 executed in 374.63 s. Best fitness value: -566.1524
# Generation 338 executed in 326.55 s. Best fitness value: -539.9549
# Generation 339 executed in 344.75 s. Best fitness value: -487.9117
# Generation 340 executed in 337.22 s. Best fitness value: -550.7667
# Generation 341 executed in 343.55 s. Best fitness value: -486.787
# Generation 342 executed in 344.7 s. Best fitness value: -543.3889
# Generation 343 executed in 335.96 s. Best fitness value: -556.7451
# Generation 344 executed in 323.88 s. Best fitness value: -577.7165
# Generation 345 executed in 314.6 s. Best fitness value: -557.9938
# Generation 346 executed in 325.4 s. Best fitness value: -495.2321
# Generation 347 executed in 334.51 s. Best fitness value: -522.9625
# Generation 348 executed in 289.22 s. Best fitness value: -503.6265
# Generation 349 executed in 316.38 s. Best fitness value: -451.4693
# Generation 350 executed in 299.51 s. Best fitness value: -537.0999
# Generation 351 executed in 296.45 s. Best fitness value: -516.7079
# Generation 352 executed in 391.04 s. Best fitness value: -485.2203
# Generation 353 executed in 442.85 s. Best fitness value: -506.6738
# Generation 354 executed in 470.65 s. Best fitness value: -526.7735
# Generation 355 executed in 463.02 s. Best fitness value: -519.3853
# Generation 356 executed in 444.95 s. Best fitness value: -480.754
# Generation 357 executed in 435.78 s. Best fitness value: -510.3429
# Generation 358 executed in 432.07 s. Best fitness value: -512.3291
# Generation 359 executed in 443.65 s. Best fitness value: -526.9667
# Generation 360 executed in 411.02 s. Best fitness value: -504.5615
# Generation 361 executed in 474.89 s. Best fitness value: -526.6969
# Generation 362 executed in 468.46 s. Best fitness value: -548.5006
# Generation 363 executed in 481.91 s. Best fitness value: -542.1412
# Generation 364 executed in 490.5 s. Best fitness value: -498.7646
# Generation 365 executed in 523.03 s. Best fitness value: -520.1384
# Generation 366 executed in 443.17 s. Best fitness value: -525.5266
# Generation 367 executed in 434.33 s. Best fitness value: -528.2581
# Generation 368 executed in 467.69 s. Best fitness value: -568.1434
# Generation 369 executed in 468.37 s. Best fitness value: -563.4096
# Generation 370 executed in 353.09 s. Best fitness value: -529.5997
# Generation 371 executed in 360.99 s. Best fitness value: -509.8596
# Generation 372 executed in 353.0 s. Best fitness value: -567.2687
# Generation 373 executed in 387.56 s. Best fitness value: -487.6116
# Generation 374 executed in 374.92 s. Best fitness value: -528.5542
# Generation 375 executed in 384.29 s. Best fitness value: -558.7646
# Generation 376 executed in 376.21 s. Best fitness value: -518.2799
# Generation 377 executed in 298.74 s. Best fitness value: -583.8379
# Generation 378 executed in 289.46 s. Best fitness value: -531.8185
# Generation 379 executed in 292.65 s. Best fitness value: -558.3713
# Generation 380 executed in 294.28 s. Best fitness value: -534.3146
# Generation 381 executed in 303.38 s. Best fitness value: -551.9297
# Generation 382 executed in 300.27 s. Best fitness value: -531.5989
# Generation 383 executed in 295.39 s. Best fitness value: -551.6738
# Generation 384 executed in 297.25 s. Best fitness value: -563.0219
# Generation 385 executed in 296.72 s. Best fitness value: -576.0396
# Generation 386 executed in 281.41 s. Best fitness value: -556.997
# Generation 387 executed in 283.05 s. Best fitness value: -557.3552
# Generation 388 executed in 278.42 s. Best fitness value: -519.8589
# Generation 389 executed in 284.13 s. Best fitness value: -528.1024
# Generation 390 executed in 284.62 s. Best fitness value: -504.1275
# Generation 391 executed in 282.1 s. Best fitness value: -553.2844
# Generation 392 executed in 294.32 s. Best fitness value: -530.5663
# Generation 393 executed in 325.9 s. Best fitness value: -509.9521
# Generation 394 executed in 304.51 s. Best fitness value: -495.4971
# Generation 395 executed in 292.75 s. Best fitness value: -550.3515
# Generation 396 executed in 295.92 s. Best fitness value: -541.6355
# Generation 397 executed in 301.24 s. Best fitness value: -521.9916
# Generation 398 executed in 297.42 s. Best fitness value: -535.0181
# Generation 399 executed in 286.69 s. Best fitness value: -564.7373
# Generation 400 executed in 295.11 s. Best fitness value: -540.9428
# Generation 401 executed in 299.99 s. Best fitness value: -576.7576
# Generation 402 executed in 299.4 s. Best fitness value: -531.7614
# Generation 403 executed in 298.76 s. Best fitness value: -506.523
# Generation 404 executed in 296.98 s. Best fitness value: -559.5232
# Generation 405 executed in 318.25 s. Best fitness value: -553.1328
# Generation 406 executed in 297.29 s. Best fitness value: -527.1697
# Generation 407 executed in 298.69 s. Best fitness value: -548.5579
# Generation 408 executed in 305.98 s. Best fitness value: -558.1293
# Generation 409 executed in 307.38 s. Best fitness value: -519.6323
# Generation 410 executed in 309.56 s. Best fitness value: -461.3447
# Generation 411 executed in 304.34 s. Best fitness value: -587.1935
# Generation 412 executed in 299.1 s. Best fitness value: -525.7857
# Generation 413 executed in 307.13 s. Best fitness value: -521.937
# Generation 414 executed in 300.07 s. Best fitness value: -518.3109
# Generation 415 executed in 305.4 s. Best fitness value: -563.2916
# Generation 416 executed in 299.51 s. Best fitness value: -525.6726
# Generation 417 executed in 303.28 s. Best fitness value: -524.0021
# Generation 418 executed in 307.39 s. Best fitness value: -531.6724
# Generation 419 executed in 309.24 s. Best fitness value: -531.5237
# Generation 420 executed in 312.41 s. Best fitness value: -518.3798
# Generation 421 executed in 325.3 s. Best fitness value: -479.1009
# Generation 422 executed in 303.98 s. Best fitness value: -516.3719
# Generation 423 executed in 305.47 s. Best fitness value: -466.6218
# Generation 424 executed in 304.28 s. Best fitness value: -546.6613
# Generation 425 executed in 308.79 s. Best fitness value: -528.3768
# Generation 426 executed in 297.71 s. Best fitness value: -505.391
# Generation 427 executed in 306.87 s. Best fitness value: -519.1857
# Generation 428 executed in 303.48 s. Best fitness value: -507.8738
# Generation 429 executed in 309.72 s. Best fitness value: -523.9371
# Generation 430 executed in 301.3 s. Best fitness value: -532.0758
# Generation 431 executed in 307.8 s. Best fitness value: -549.9297
# Generation 432 executed in 298.29 s. Best fitness value: -543.4957
# Generation 433 executed in 294.88 s. Best fitness value: -489.769
# Generation 434 executed in 307.77 s. Best fitness value: -554.0524
# Generation 435 executed in 296.32 s. Best fitness value: -561.5842
# Generation 436 executed in 291.9 s. Best fitness value: -523.9047
# Generation 437 executed in 305.93 s. Best fitness value: -474.4499
# Generation 438 executed in 284.79 s. Best fitness value: -548.4227
# Generation 439 executed in 258.91 s. Best fitness value: -551.3212
# Generation 440 executed in 296.96 s. Best fitness value: -549.1459
# Generation 441 executed in 284.98 s. Best fitness value: -549.7239
# Generation 442 executed in 295.33 s. Best fitness value: -509.8118
# Generation 443 executed in 293.87 s. Best fitness value: -530.7401
# Generation 444 executed in 302.38 s. Best fitness value: -552.6656
# Generation 445 executed in 289.16 s. Best fitness value: -546.9174
# Generation 446 executed in 301.38 s. Best fitness value: -552.7822
# Generation 447 executed in 326.09 s. Best fitness value: -540.2795
# Generation 448 executed in 300.14 s. Best fitness value: -402.1059
# Generation 449 executed in 345.14 s. Best fitness value: -533.7591
# Generation 450 executed in 331.97 s. Best fitness value: -499.0688
# Generation 451 executed in 349.07 s. Best fitness value: -532.6188
# Generation 452 executed in 326.3 s. Best fitness value: -477.6838
# Generation 453 executed in 319.87 s. Best fitness value: -490.8146
# Generation 454 executed in 348.02 s. Best fitness value: -520.028
# Generation 455 executed in 340.01 s. Best fitness value: -467.3955
# Generation 456 executed in 327.81 s. Best fitness value: -454.9428
# Generation 457 executed in 324.05 s. Best fitness value: -524.5259
# Generation 458 executed in 325.57 s. Best fitness value: -529.7122
# Generation 459 executed in 336.3 s. Best fitness value: -501.9977
# Generation 460 executed in 344.29 s. Best fitness value: -500.4941
# Generation 461 executed in 331.88 s. Best fitness value: -540.1572
# Generation 462 executed in 295.31 s. Best fitness value: -532.8986
# Generation 463 executed in 290.52 s. Best fitness value: -520.0474
# Generation 464 executed in 282.1 s. Best fitness value: -544.4912
# Generation 465 executed in 294.19 s. Best fitness value: -539.3575
# Generation 466 executed in 299.59 s. Best fitness value: -512.4761
# Generation 467 executed in 290.56 s. Best fitness value: -525.7428
# Generation 468 executed in 277.44 s. Best fitness value: -522.1676
# Generation 469 executed in 278.45 s. Best fitness value: -521.0887
# Generation 470 executed in 292.69 s. Best fitness value: -549.3089
# Generation 471 executed in 285.28 s. Best fitness value: -553.166
# Generation 472 executed in 289.81 s. Best fitness value: -516.9775
# Generation 473 executed in 284.39 s. Best fitness value: -526.8515
# Generation 474 executed in 280.97 s. Best fitness value: -511.6656
# Generation 475 executed in 293.93 s. Best fitness value: -524.5357
# Generation 476 executed in 291.68 s. Best fitness value: -544.2539
# Generation 477 executed in 306.01 s. Best fitness value: -566.1307
# Generation 478 executed in 292.47 s. Best fitness value: -509.1642
# Generation 479 executed in 295.9 s. Best fitness value: -580.207
# Generation 480 executed in 296.26 s. Best fitness value: -558.3531
# Generation 481 executed in 284.1 s. Best fitness value: -476.354
# Generation 482 executed in 288.36 s. Best fitness value: -521.4843
# Generation 483 executed in 296.78 s. Best fitness value: -560.5612
# Generation 484 executed in 273.28 s. Best fitness value: -497.6508
# Generation 485 executed in 288.43 s. Best fitness value: -545.4265
# Generation 486 executed in 297.88 s. Best fitness value: -552.595
# Generation 487 executed in 292.83 s. Best fitness value: -506.6502
# Generation 488 executed in 286.39 s. Best fitness value: -476.6695
# Generation 489 executed in 294.02 s. Best fitness value: -491.4888
# Generation 490 executed in 290.81 s. Best fitness value: -559.0166
# Generation 491 executed in 287.82 s. Best fitness value: -529.3196
# Generation 492 executed in 294.91 s. Best fitness value: -539.3266
# Generation 493 executed in 281.04 s. Best fitness value: -559.8663
# Generation 494 executed in 278.02 s. Best fitness value: -535.911
# Generation 495 executed in 295.11 s. Best fitness value: -536.677
# Generation 496 executed in 282.15 s. Best fitness value: -518.2778
# Generation 497 executed in 280.17 s. Best fitness value: -538.3845
# Generation 498 executed in 269.11 s. Best fitness value: -539.6032
# Generation 499 executed in 262.7 s. Best fitness value: -564.7802
# Generation 500 executed in 282.28 s. Best fitness value: -533.6256
# Generation 501 executed in 266.78 s. Best fitness value: -549.7177
# Generation 502 executed in 277.87 s. Best fitness value: -538.669
# Generation 503 executed in 290.49 s. Best fitness value: -538.5356
# Generation 504 executed in 295.26 s. Best fitness value: -512.8293
# Generation 505 executed in 309.4 s. Best fitness value: -533.1312
# Generation 506 executed in 285.36 s. Best fitness value: -527.8884
# Generation 507 executed in 297.16 s. Best fitness value: -542.7879
# Generation 508 executed in 299.72 s. Best fitness value: -515.8947
# Generation 509 executed in 278.14 s. Best fitness value: -544.5558
# Generation 510 executed in 292.47 s. Best fitness value: -549.2925
# Generation 511 executed in 290.84 s. Best fitness value: -540.2584
# Generation 512 executed in 289.3 s. Best fitness value: -532.9924
# Generation 513 executed in 300.42 s. Best fitness value: -543.4485
# Generation 514 executed in 296.18 s. Best fitness value: -545.5097
# Generation 515 executed in 292.22 s. Best fitness value: -502.7952
# Generation 516 executed in 293.78 s. Best fitness value: -517.2474
# Generation 517 executed in 299.32 s. Best fitness value: -566.0055
# Generation 518 executed in 306.04 s. Best fitness value: -519.2601
# Generation 519 executed in 288.0 s. Best fitness value: -553.9973
# Generation 520 executed in 286.94 s. Best fitness value: -555.0965
# Generation 521 executed in 297.95 s. Best fitness value: -530.5247
# Generation 522 executed in 281.68 s. Best fitness value: -553.3549
# Generation 523 executed in 279.22 s. Best fitness value: -543.9567
# Generation 524 executed in 291.0 s. Best fitness value: -554.2194
# Generation 525 executed in 279.35 s. Best fitness value: -550.1002
# Generation 526 executed in 291.56 s. Best fitness value: -542.5354
# Generation 527 executed in 277.24 s. Best fitness value: -558.46
# Generation 528 executed in 291.87 s. Best fitness value: -550.9599
# Generation 529 executed in 288.45 s. Best fitness value: -551.7636
# Generation 530 executed in 293.71 s. Best fitness value: -544.3356
# Generation 531 executed in 286.37 s. Best fitness value: -539.5405
# Generation 532 executed in 294.27 s. Best fitness value: -531.8221
# Generation 533 executed in 288.42 s. Best fitness value: -546.3131
# Generation 534 executed in 296.19 s. Best fitness value: -565.228
# Generation 535 executed in 264.14 s. Best fitness value: -533.3313
# Generation 536 executed in 290.11 s. Best fitness value: -503.1611
# Generation 537 executed in 286.61 s. Best fitness value: -573.6441
# Generation 538 executed in 277.63 s. Best fitness value: -541.1638
# Generation 539 executed in 288.4 s. Best fitness value: -530.9608
# Generation 540 executed in 297.36 s. Best fitness value: -526.907
# Generation 541 executed in 285.46 s. Best fitness value: -542.5278
# Generation 542 executed in 290.93 s. Best fitness value: -553.703
# Generation 543 executed in 279.97 s. Best fitness value: -540.988
# Generation 544 executed in 295.11 s. Best fitness value: -580.3068
# Generation 545 executed in 281.47 s. Best fitness value: -539.2214
# Generation 546 executed in 301.07 s. Best fitness value: -504.1818
# Generation 547 executed in 287.53 s. Best fitness value: -545.3839
# Generation 548 executed in 294.98 s. Best fitness value: -508.5632
# Generation 549 executed in 295.79 s. Best fitness value: -493.8602
# Generation 550 executed in 294.25 s. Best fitness value: -517.848
# Generation 551 executed in 302.93 s. Best fitness value: -533.6276
# Generation 552 executed in 293.13 s. Best fitness value: -559.5171
# Generation 553 executed in 295.23 s. Best fitness value: -537.9706
# Generation 554 executed in 302.16 s. Best fitness value: -530.7068
# Generation 555 executed in 297.37 s. Best fitness value: -591.9291
# Generation 556 executed in 303.66 s. Best fitness value: -552.4389
# Generation 557 executed in 298.44 s. Best fitness value: -525.9107
# Generation 558 executed in 298.37 s. Best fitness value: -564.4476
# Generation 559 executed in 294.12 s. Best fitness value: -556.3372
# Generation 560 executed in 293.18 s. Best fitness value: -498.6599
# Generation 561 executed in 308.29 s. Best fitness value: -531.5843
# Generation 562 executed in 287.88 s. Best fitness value: -535.0882
# Generation 563 executed in 297.95 s. Best fitness value: -538.3115
# Generation 564 executed in 305.04 s. Best fitness value: -497.9462
# Generation 565 executed in 292.48 s. Best fitness value: -540.5914
# Generation 566 executed in 302.48 s. Best fitness value: -540.5366
# Generation 567 executed in 298.46 s. Best fitness value: -547.0659
# Generation 568 executed in 301.92 s. Best fitness value: -555.7175
# Generation 569 executed in 295.14 s. Best fitness value: -545.0512
# Generation 570 executed in 304.96 s. Best fitness value: -539.595
# Generation 571 executed in 301.4 s. Best fitness value: -562.5926
# Generation 572 executed in 306.25 s. Best fitness value: -509.506
# Generation 573 executed in 296.13 s. Best fitness value: -552.1058
# Generation 574 executed in 290.35 s. Best fitness value: -524.0168
# Generation 575 executed in 291.54 s. Best fitness value: -558.974
# Generation 576 executed in 305.51 s. Best fitness value: -555.7554
# Generation 577 executed in 303.33 s. Best fitness value: -570.8081
# Generation 578 executed in 297.88 s. Best fitness value: -520.6462
# Generation 579 executed in 292.84 s. Best fitness value: -551.5385
# Generation 580 executed in 306.4 s. Best fitness value: -542.5227
# Generation 581 executed in 288.34 s. Best fitness value: -521.5424
# Generation 582 executed in 292.38 s. Best fitness value: -571.6768
# Generation 583 executed in 292.43 s. Best fitness value: -571.4232
# Generation 584 executed in 307.43 s. Best fitness value: -533.6966
# Generation 585 executed in 361.83 s. Best fitness value: -549.9274
# Generation 586 executed in 299.06 s. Best fitness value: -565.7621
# Generation 587 executed in 299.38 s. Best fitness value: -547.1416
# Generation 588 executed in 285.57 s. Best fitness value: -570.3437
# Generation 589 executed in 322.55 s. Best fitness value: -527.8016
# Generation 590 executed in 307.44 s. Best fitness value: -542.759
# Generation 591 executed in 288.67 s. Best fitness value: -533.6404
# Generation 592 executed in 304.66 s. Best fitness value: -498.4197
# Generation 593 executed in 306.4 s. Best fitness value: -539.357
# Generation 594 executed in 316.04 s. Best fitness value: -530.5808
# Generation 595 executed in 312.09 s. Best fitness value: -500.5681
# Generation 596 executed in 309.11 s. Best fitness value: -557.4927
# Generation 597 executed in 301.63 s. Best fitness value: -552.757
# Generation 598 executed in 309.77 s. Best fitness value: -547.447
# Generation 599 executed in 300.77 s. Best fitness value: -556.5068
# Generation 600 executed in 310.98 s. Best fitness value: -518.7382

# %%
# with open('best_model_LOC.pickle', 'wb') as handle:
#     pickle.dump(best_model_LOC, handle, protocol=pickle.HIGHEST_PROTOCOL)

# with open('fitness_values_LOC.pickle', 'wb') as handle:
#     pickle.dump(fitness_values_LOC, handle, protocol=pickle.HIGHEST_PROTOCOL)

with open('best_model_LOC.pickle', 'rb') as handle:
    best_model_LOC = pickle.load(handle)

# %% [markdown]
# ## Top-patches convolutional feature extractor

# %%
FEAT_EXTRACTOR         = "CONV"
lstm_hidden_dim        = 16

model=Agent(observation_space_size,stride,window,channels,
            attention_out_dim,K,lstm_hidden_dim,eps,
            CONTINUOUS,FEAT_EXTRACTOR)
model
# Out:
# Agent(
#   (grayscaler): Grayscale(num_output_channels=1)
#   (attention): Attention_module(
#     (attention1): Linear(in_features=192, out_features=4, bias=True)
#     (attention2): Linear(in_features=192, out_features=4, bias=True)
#   )
#   (patch_extractor): Patcher_module()
#   (slicer): Slicer_module()
#   (feat_extractor): Feature_extractor_module(
#     (convolutions): Sequential(
#       (0): Conv2d(3, 10, kernel_size=(3, 3), stride=(1, 1))
#       (1): ReLU()
#       (2): Conv2d(10, 10, kernel_size=(3, 3), stride=(1, 1))
#       (3): ReLU()
#       (4): Conv2d(10, 10, kernel_size=(3, 3), stride=(1, 1))
#       (5): ReLU()
#       (6): Conv2d(10, 2, kernel_size=(2, 2), stride=(1, 1))
#     )
#   )
#   (controller): Controller_module(
#     (linear): Linear(in_features=16, out_features=5, bias=True)
#   )
#   (rnn): LSTM(20, 16, batch_first=True)
# )

# %%
print("Model's state_dict:")
old_dict=store_state_dict(model)
old_dict
# Out:
# Model's state_dict:
# {'attention.attention1.weight': {'size': 768, 'shape': (4, 192)},
#  'attention.attention1.bias': {'size': 4, 'shape': (4,)},
#  'attention.attention2.weight': {'size': 768, 'shape': (4, 192)},
#  'attention.attention2.bias': {'size': 4, 'shape': (4,)},
#  'feat_extractor.convolutions.0.weight': {'size': 270, 'shape': (10, 3, 3, 3)},
#  'feat_extractor.convolutions.0.bias': {'size': 10, 'shape': (10,)},
#  'feat_extractor.convolutions.2.weight': {'size': 900,
#   'shape': (10, 10, 3, 3)},
#  'feat_extractor.convolutions.2.bias': {'size': 10, 'shape': (10,)},
#  'feat_extractor.convolutions.4.weight': {'size': 900,
#   'shape': (10, 10, 3, 3)},
#  'feat_extractor.convolutions.4.bias': {'size': 10, 'shape': (10,)},
#  'feat_extractor.convolutions.6.weight': {'size': 80, 'shape': (2, 10, 2, 2)},
#  'feat_extractor.convolutions.6.bias': {'size': 2, 'shape': (2,)},
#  'controller.linear.weight': {'size': 80, 'shape': (5, 16)},
#  'controller.linear.bias': {'size': 5, 'shape': (5,)},
#  'rnn.weight_ih_l0': {'size': 1280, 'shape': (64, 20)},
#  'rnn.weight_hh_l0': {'size': 1024, 'shape': (64, 16)},
#  'rnn.bias_ih_l0': {'size': 64, 'shape': (64,)},
#  'rnn.bias_hh_l0': {'size': 64, 'shape': (64,)}}

# %%
n=get_n_params(model)
print("Model contains {} parameters.".format(n))
# Out:
# Model contains 6243 parameters.

# %%
es                = cma.CMAEvolutionStrategy(n * [0], 0.01,{"seed":12345})
env               = gym.make("CarRacing-v2",continuous=CONTINUOUS)
max_generation    = 150
gamma             = 0.999
autoencoder       = None

fitness_values_CONV, best_model_CONV  = train(es,env,model,max_generation,autoencoder,old_dict,gamma)
# Out:
# (15_w,30)-aCMA-ES (mu_w=8.6,w_1=20%) in dimension 6243 (seed=12345, Tue Sep 13 11:06:24 2022)
# Generation 1 executed in 281.65 s. Best fitness value: 27.2262
# Generation 2 executed in 245.27 s. Best fitness value: -46.498
# Generation 3 executed in 154.21 s. Best fitness value: -43.3922
# Generation 4 executed in 176.45 s. Best fitness value: -56.0729
# Generation 5 executed in 143.06 s. Best fitness value: -59.2813
# Generation 6 executed in 183.93 s. Best fitness value: -56.5282
# Generation 7 executed in 169.21 s. Best fitness value: -66.0006
# Generation 8 executed in 156.68 s. Best fitness value: -54.956
# Generation 9 executed in 135.73 s. Best fitness value: -57.9008
# Generation 10 executed in 165.72 s. Best fitness value: -50.3694
# Generation 11 executed in 129.21 s. Best fitness value: -48.8621
# Generation 12 executed in 134.58 s. Best fitness value: -57.078
# Generation 13 executed in 181.37 s. Best fitness value: -36.8055
# Generation 14 executed in 174.27 s. Best fitness value: -83.6315
# Generation 15 executed in 198.28 s. Best fitness value: -53.4758
# Generation 16 executed in 170.6 s. Best fitness value: -46.7853
# Generation 17 executed in 178.4 s. Best fitness value: -53.2771
# Generation 18 executed in 141.87 s. Best fitness value: -48.6906
# Generation 19 executed in 166.3 s. Best fitness value: -54.5533
# Generation 20 executed in 163.37 s. Best fitness value: -52.9329
# Generation 21 executed in 152.05 s. Best fitness value: -36.6461
# Generation 22 executed in 146.0 s. Best fitness value: -43.7272
# Generation 23 executed in 142.8 s. Best fitness value: -61.2966
# Generation 24 executed in 142.09 s. Best fitness value: -77.7543
# Generation 25 executed in 151.93 s. Best fitness value: -41.191
# Generation 26 executed in 146.02 s. Best fitness value: -47.8742
# Generation 27 executed in 189.38 s. Best fitness value: -22.6258
# Generation 28 executed in 167.59 s. Best fitness value: -60.5132
# Generation 29 executed in 173.96 s. Best fitness value: -34.384
# Generation 30 executed in 168.15 s. Best fitness value: -60.624
# Generation 31 executed in 131.92 s. Best fitness value: -71.8103
# Generation 32 executed in 139.53 s. Best fitness value: -45.5169
# Generation 33 executed in 152.07 s. Best fitness value: -49.8447
# Generation 34 executed in 142.54 s. Best fitness value: -64.8346
# Generation 35 executed in 145.79 s. Best fitness value: -56.7219
# Generation 36 executed in 147.82 s. Best fitness value: -58.8749
# Generation 37 executed in 147.61 s. Best fitness value: -64.749
# Generation 38 executed in 138.23 s. Best fitness value: -57.0213
# Generation 39 executed in 156.71 s. Best fitness value: -49.8451
# Generation 40 executed in 231.77 s. Best fitness value: -65.6013
# Generation 41 executed in 147.63 s. Best fitness value: -67.0826
# Generation 42 executed in 159.13 s. Best fitness value: -40.9266
# Generation 43 executed in 158.97 s. Best fitness value: -54.5903
# Generation 44 executed in 157.42 s. Best fitness value: -57.8732
# Generation 45 executed in 176.59 s. Best fitness value: -74.6053
# Generation 46 executed in 179.58 s. Best fitness value: -48.6382
# Generation 47 executed in 150.38 s. Best fitness value: -71.995
# Generation 48 executed in 157.21 s. Best fitness value: -68.9971
# Generation 49 executed in 181.33 s. Best fitness value: -64.0098
# Generation 50 executed in 164.91 s. Best fitness value: -40.3432
# Generation 51 executed in 152.26 s. Best fitness value: -52.315
# Generation 52 executed in 141.93 s. Best fitness value: -47.2757
# Generation 53 executed in 128.55 s. Best fitness value: -61.4424
# Generation 54 executed in 142.99 s. Best fitness value: -57.3005
# Generation 55 executed in 145.37 s. Best fitness value: -54.6023
# Generation 56 executed in 145.15 s. Best fitness value: -74.3046
# Generation 57 executed in 154.72 s. Best fitness value: -84.902
# Generation 58 executed in 165.28 s. Best fitness value: -69.5428
# Generation 59 executed in 143.82 s. Best fitness value: -61.8506
# Generation 60 executed in 166.82 s. Best fitness value: -54.9698
# Generation 61 executed in 146.7 s. Best fitness value: -69.4296
# Generation 62 executed in 147.92 s. Best fitness value: -64.1643
# Generation 63 executed in 148.31 s. Best fitness value: -53.7236
# Generation 64 executed in 138.85 s. Best fitness value: -69.3084
# Generation 65 executed in 152.46 s. Best fitness value: -38.2772
# Generation 66 executed in 146.75 s. Best fitness value: -31.5191
# Generation 67 executed in 145.61 s. Best fitness value: -51.7278
# Generation 68 executed in 150.68 s. Best fitness value: -52.6615
# Generation 69 executed in 159.36 s. Best fitness value: -68.2486
# Generation 70 executed in 162.34 s. Best fitness value: -56.1761
# Generation 71 executed in 180.6 s. Best fitness value: -47.4346
# Generation 72 executed in 180.25 s. Best fitness value: -69.1344
# Generation 73 executed in 166.41 s. Best fitness value: -38.1999
# Generation 74 executed in 150.45 s. Best fitness value: -46.3462
# Generation 75 executed in 181.53 s. Best fitness value: -66.2537
# Generation 76 executed in 133.55 s. Best fitness value: -64.86
# Generation 77 executed in 135.09 s. Best fitness value: -44.6955
# Generation 78 executed in 158.4 s. Best fitness value: -63.3273
# Generation 79 executed in 234.1 s. Best fitness value: -54.0043
# Generation 80 executed in 156.79 s. Best fitness value: -66.7812
# Generation 81 executed in 140.94 s. Best fitness value: -48.404
# Generation 82 executed in 156.96 s. Best fitness value: -47.1371
# Generation 83 executed in 137.47 s. Best fitness value: -57.1841
# Generation 84 executed in 175.69 s. Best fitness value: -35.0519
# Generation 85 executed in 132.33 s. Best fitness value: -48.5471
# Generation 86 executed in 146.66 s. Best fitness value: -62.3714
# Generation 87 executed in 169.79 s. Best fitness value: -53.4697
# Generation 88 executed in 219.77 s. Best fitness value: -53.5607
# Generation 89 executed in 174.79 s. Best fitness value: -51.6995
# Generation 90 executed in 188.64 s. Best fitness value: -51.2962
# Generation 91 executed in 177.91 s. Best fitness value: -58.1223
# Generation 92 executed in 186.47 s. Best fitness value: -48.836
# Generation 93 executed in 179.99 s. Best fitness value: -52.9688
# Generation 94 executed in 147.96 s. Best fitness value: -56.5198
# Generation 95 executed in 266.63 s. Best fitness value: -30.2025
# Generation 96 executed in 187.74 s. Best fitness value: -34.0972
# Generation 97 executed in 153.0 s. Best fitness value: -52.7447
# Generation 98 executed in 130.37 s. Best fitness value: -83.6347
# Generation 99 executed in 156.23 s. Best fitness value: -62.3364
# Generation 100 executed in 149.75 s. Best fitness value: -53.9708
# Generation 101 executed in 145.7 s. Best fitness value: -42.91
# Generation 102 executed in 135.26 s. Best fitness value: -43.7159
# Generation 103 executed in 149.52 s. Best fitness value: -61.8085
# Generation 104 executed in 145.42 s. Best fitness value: -55.4483
# Generation 105 executed in 137.2 s. Best fitness value: -50.2689
# Generation 106 executed in 134.28 s. Best fitness value: -47.2552
# Generation 107 executed in 134.3 s. Best fitness value: -68.2736
# Generation 108 executed in 137.01 s. Best fitness value: -65.1279
# Generation 109 executed in 134.2 s. Best fitness value: -62.0382
# Generation 110 executed in 152.98 s. Best fitness value: -53.7922
# Generation 111 executed in 154.42 s. Best fitness value: -44.4478
# Generation 112 executed in 152.04 s. Best fitness value: -67.5484
# Generation 113 executed in 151.82 s. Best fitness value: -85.8213
# Generation 114 executed in 137.75 s. Best fitness value: -58.1219
# Generation 115 executed in 145.37 s. Best fitness value: -70.6159
# Generation 116 executed in 133.57 s. Best fitness value: -43.6345
# Generation 117 executed in 162.17 s. Best fitness value: -54.9426
# Generation 118 executed in 180.88 s. Best fitness value: -45.8992
# Generation 119 executed in 138.17 s. Best fitness value: -57.0099
# Generation 120 executed in 138.74 s. Best fitness value: -69.175
# Generation 121 executed in 131.96 s. Best fitness value: -61.6799
# Generation 122 executed in 137.41 s. Best fitness value: -45.0967
# Generation 123 executed in 135.06 s. Best fitness value: -38.8535
# Generation 124 executed in 126.57 s. Best fitness value: -71.7914
# Generation 125 executed in 137.64 s. Best fitness value: -52.3444
# Generation 126 executed in 138.87 s. Best fitness value: -33.0462
# Generation 127 executed in 134.74 s. Best fitness value: -76.2188
# Generation 128 executed in 132.85 s. Best fitness value: -63.6681
# Generation 129 executed in 133.69 s. Best fitness value: -36.6917
# Generation 130 executed in 141.56 s. Best fitness value: -53.6397
# Generation 131 executed in 135.62 s. Best fitness value: -44.1195
# Generation 132 executed in 149.91 s. Best fitness value: -63.1676
# Generation 133 executed in 133.48 s. Best fitness value: -54.7652
# Generation 134 executed in 136.5 s. Best fitness value: -46.7108
# Generation 135 executed in 139.6 s. Best fitness value: -48.0066
# Generation 136 executed in 139.94 s. Best fitness value: -71.8625
# Generation 137 executed in 140.12 s. Best fitness value: -33.6148
# Generation 138 executed in 137.29 s. Best fitness value: -56.8935
# Generation 139 executed in 141.83 s. Best fitness value: -60.9417
# Generation 140 executed in 148.07 s. Best fitness value: -87.5141
# Generation 141 executed in 142.14 s. Best fitness value: -54.2936
# Generation 142 executed in 135.74 s. Best fitness value: -74.5673
# Generation 143 executed in 132.54 s. Best fitness value: -40.5804
# Generation 144 executed in 129.5 s. Best fitness value: -44.9921
# Generation 145 executed in 146.97 s. Best fitness value: -63.845
# Generation 146 executed in 129.05 s. Best fitness value: -45.6448
# Generation 147 executed in 149.58 s. Best fitness value: -54.7666
# Generation 148 executed in 144.9 s. Best fitness value: -49.9503
# Generation 149 executed in 141.92 s. Best fitness value: -42.0645
# Generation 150 executed in 139.64 s. Best fitness value: -49.9979

# %%
with open('best_model_CONV.pickle', 'wb') as handle:
    pickle.dump(best_model_CONV, handle, protocol=pickle.HIGHEST_PROTOCOL)

with open('fitness_values_CONV.pickle', 'wb') as handle:
    pickle.dump(fitness_values_CONV, handle, protocol=pickle.HIGHEST_PROTOCOL)

# with open('best_model_CONV.pickle', 'rb') as handle:
#     best_model_CONV = pickle.load(handle)

# %% [markdown]
# ## Autoencoder training

# %%
env               = gym.make("CarRacing-v2",continuous=CONTINUOUS)
FEAT_EXTRACTOR    = "LOC"

model             = Agent(observation_space_size,stride,window,channels,
                          attention_out_dim,K,lstm_hidden_dim,eps,
                          CONTINUOUS,FEAT_EXTRACTOR)
old_dict          = store_state_dict(model)

autoencoder       = Autoencoder()
autoencoder.train()

ae_losses     = {"train":[],"val":[]}
n_episodes    = 30
learning_rate = 1e-3
criterion     = nn.MSELoss() # mean square error loss
optimizer     = torch.optim.Adam(autoencoder.parameters(),
                                 lr=learning_rate,
                                 weight_decay=1e-5)
torch.set_grad_enabled(True)
for i in range(n_episodes):
  

    model       = load_state_dict(model, best_model_LOC, old_dict)
    observation = state_processer(env.reset())
    ob_tensor   = torch.cat((observation,observation,observation),dim=-1)

    done        = False
    train_loss  = []
    val_loss    = []
    step        = 0
    sum_reward  = 0
    while (not done) and (sum_reward < 1000):
        action, top_patches                  = model(ob_tensor)
        observation_next, reward, done, info = env.step(action)
        observation_next                     = state_processer(observation_next)
        ob_tensor                            = cycle_observation(ob_tensor,observation_next)
        sum_reward                          += reward
        step                                += 1
        if autoencoder:
            autoencoder.train()
            top_patches                   = top_patches[torch.randperm(top_patches.size()[0])]
            top_patch_train,top_patch_val = top_patches[:8],top_patches[8:]
            code,reconstructions          = autoencoder(top_patch_train)
            loss                          = criterion(reconstructions, top_patch_train.permute(0,3,1,2))
            loss.backward(retain_graph=True)
            optimizer.step()
            optimizer.zero_grad()
            train_loss.append(loss.item())

            autoencoder.eval()
            code,reconstructions          = autoencoder(top_patch_val)
            loss                          = criterion(reconstructions, top_patch_val.permute(0,3,1,2))
            val_loss.append(loss.item())

    ae_losses["train"].append(train_loss)
    ae_losses["val"].append(val_loss)
    print("Episode {} lasted {} frames. ### Sum reward : {} ### Train loss : {} Validation loss : {}".\
        format(i,step,round(sum_reward,2),round(np.mean(train_loss),5),round(np.mean(val_loss),5)))
# Out:
# Episode 0 lasted 1000 frames. ### Sum reward : 684.51 ### Train loss : 0.01281 Validation loss : 0.01283
# Episode 1 lasted 1000 frames. ### Sum reward : 766.67 ### Train loss : 0.00755 Validation loss : 0.00732
# Episode 2 lasted 1000 frames. ### Sum reward : 842.57 ### Train loss : 0.00703 Validation loss : 0.00684
# Episode 3 lasted 1000 frames. ### Sum reward : 623.03 ### Train loss : 0.00563 Validation loss : 0.00567
# Episode 4 lasted 1000 frames. ### Sum reward : 808.42 ### Train loss : 0.00519 Validation loss : 0.00487
# Episode 5 lasted 390 frames. ### Sum reward : 52.28 ### Train loss : 0.00561 Validation loss : 0.00509
# Episode 6 lasted 1000 frames. ### Sum reward : 263.35 ### Train loss : 0.00514 Validation loss : 0.00513
# Episode 7 lasted 1000 frames. ### Sum reward : 877.78 ### Train loss : 0.00412 Validation loss : 0.00414
# Episode 8 lasted 1000 frames. ### Sum reward : 719.55 ### Train loss : 0.00457 Validation loss : 0.00441
# Episode 9 lasted 879 frames. ### Sum reward : 912.1 ### Train loss : 0.00449 Validation loss : 0.00438
# Episode 10 lasted 1000 frames. ### Sum reward : 796.1 ### Train loss : 0.0037 Validation loss : 0.00366
# Episode 11 lasted 1000 frames. ### Sum reward : 644.74 ### Train loss : 0.00497 Validation loss : 0.00468
# Episode 12 lasted 1000 frames. ### Sum reward : 779.6 ### Train loss : 0.00413 Validation loss : 0.00399
# Episode 13 lasted 1000 frames. ### Sum reward : 767.99 ### Train loss : 0.00433 Validation loss : 0.00403
# Episode 14 lasted 1000 frames. ### Sum reward : 866.42 ### Train loss : 0.00419 Validation loss : 0.00419
# Episode 15 lasted 1000 frames. ### Sum reward : 723.17 ### Train loss : 0.0051 Validation loss : 0.00485
# Episode 16 lasted 1000 frames. ### Sum reward : 395.8 ### Train loss : 0.00389 Validation loss : 0.00376
# Episode 17 lasted 1000 frames. ### Sum reward : 698.48 ### Train loss : 0.00459 Validation loss : 0.00467
# Episode 18 lasted 1000 frames. ### Sum reward : 786.99 ### Train loss : 0.00371 Validation loss : 0.00358
# Episode 19 lasted 1000 frames. ### Sum reward : 839.29 ### Train loss : 0.00377 Validation loss : 0.00387
# Episode 20 lasted 1000 frames. ### Sum reward : 776.51 ### Train loss : 0.00411 Validation loss : 0.00401
# Episode 21 lasted 1000 frames. ### Sum reward : 773.79 ### Train loss : 0.00402 Validation loss : 0.00409
# Episode 22 lasted 1000 frames. ### Sum reward : 784.11 ### Train loss : 0.00382 Validation loss : 0.00375
# Episode 23 lasted 1000 frames. ### Sum reward : 666.87 ### Train loss : 0.00358 Validation loss : 0.0035
# Episode 24 lasted 1000 frames. ### Sum reward : 741.16 ### Train loss : 0.00409 Validation loss : 0.00397
# Episode 25 lasted 1000 frames. ### Sum reward : 371.76 ### Train loss : 0.00325 Validation loss : 0.00329
# Episode 26 lasted 1000 frames. ### Sum reward : 851.22 ### Train loss : 0.00409 Validation loss : 0.00387
# Episode 27 lasted 1000 frames. ### Sum reward : 887.22 ### Train loss : 0.0036 Validation loss : 0.00332
# Episode 28 lasted 1000 frames. ### Sum reward : 646.58 ### Train loss : 0.00413 Validation loss : 0.0041
# Episode 29 lasted 1000 frames. ### Sum reward : 863.27 ### Train loss : 0.00305 Validation loss : 0.00316

# %%
torch.save(autoencoder.state_dict(), "autoencoder.pth")

# %% [markdown]
# ## AE top-patches feature extractor

# %%
lstm_hidden_dim   = 256
FEAT_EXTRACTOR    = "AE"

model             = Agent(observation_space_size,stride,window,channels,
                          attention_out_dim,K,lstm_hidden_dim,eps,
                          CONTINUOUS,FEAT_EXTRACTOR)
n                 = get_n_params(model)
old_dict          = store_state_dict(model)

es                = cma.CMAEvolutionStrategy(n * [0], 0.01,{"seed":12345})
env               = gym.make("CarRacing-v2",continuous=CONTINUOUS)
max_generation    = 150
gamma             = 0.999
fitness_values_AE, best_model_AE  = train(es,env,model,max_generation,autoencoder,old_dict,gamma)
# Out:
# (13_w,27)-aCMA-ES (mu_w=7.8,w_1=22%) in dimension 2829 (seed=12345, Mon Sep 12 19:14:08 2022)
# Generation 1 executed in 353.03 s. Best fitness value: -49.706
# Generation 2 executed in 300.54 s. Best fitness value: -35.0635
# Generation 3 executed in 264.3 s. Best fitness value: -28.3324
# Generation 4 executed in 290.62 s. Best fitness value: -42.2366
# Generation 5 executed in 237.92 s. Best fitness value: -73.5846
# Generation 6 executed in 238.12 s. Best fitness value: -62.3611
# Generation 7 executed in 220.57 s. Best fitness value: -58.3146
# Generation 8 executed in 186.91 s. Best fitness value: -65.8829
# Generation 9 executed in 204.52 s. Best fitness value: -65.008
# Generation 10 executed in 181.12 s. Best fitness value: -66.9857
# Generation 11 executed in 192.92 s. Best fitness value: -86.2072
# Generation 12 executed in 217.66 s. Best fitness value: -51.8156
# Generation 13 executed in 184.81 s. Best fitness value: -54.7157
# Generation 14 executed in 195.24 s. Best fitness value: -58.9726
# Generation 15 executed in 262.99 s. Best fitness value: -45.6106
# Generation 16 executed in 253.14 s. Best fitness value: -101.169
# Generation 17 executed in 233.27 s. Best fitness value: -81.9243
# Generation 18 executed in 343.74 s. Best fitness value: -36.3725
# Generation 19 executed in 263.54 s. Best fitness value: -79.5667
# Generation 20 executed in 315.55 s. Best fitness value: -47.1209
# Generation 21 executed in 266.46 s. Best fitness value: -52.9066
# Generation 22 executed in 264.05 s. Best fitness value: -61.9074
# Generation 23 executed in 266.09 s. Best fitness value: -75.7108
# Generation 24 executed in 248.17 s. Best fitness value: -52.5185
# Generation 25 executed in 262.44 s. Best fitness value: -74.9226
# Generation 26 executed in 325.38 s. Best fitness value: -68.6076
# Generation 27 executed in 298.38 s. Best fitness value: -50.267
# Generation 28 executed in 351.47 s. Best fitness value: -91.505
# Generation 29 executed in 363.85 s. Best fitness value: -61.3791
# Generation 30 executed in 378.4 s. Best fitness value: -72.3992
# Generation 31 executed in 419.87 s. Best fitness value: -93.456
# Generation 32 executed in 369.15 s. Best fitness value: -51.6269
# Generation 33 executed in 353.17 s. Best fitness value: -86.6636
# Generation 34 executed in 293.74 s. Best fitness value: -89.0203
# Generation 35 executed in 382.69 s. Best fitness value: -23.754
# Generation 36 executed in 406.13 s. Best fitness value: -89.5579
# Generation 37 executed in 450.58 s. Best fitness value: -79.4202
# Generation 38 executed in 431.61 s. Best fitness value: -101.6983
# Generation 39 executed in 472.27 s. Best fitness value: -95.7884
# Generation 40 executed in 472.4 s. Best fitness value: -105.9197
# Generation 41 executed in 456.24 s. Best fitness value: -86.0205
# Generation 42 executed in 432.05 s. Best fitness value: -62.3821
# Generation 43 executed in 441.54 s. Best fitness value: -100.6303
# Generation 44 executed in 408.56 s. Best fitness value: -66.4335
# Generation 45 executed in 371.4 s. Best fitness value: -70.5323
# Generation 46 executed in 358.92 s. Best fitness value: -79.2952
# Generation 47 executed in 422.95 s. Best fitness value: -43.6136
# Generation 48 executed in 413.42 s. Best fitness value: -89.4785
# Generation 49 executed in 394.38 s. Best fitness value: -127.4491
# Generation 50 executed in 354.65 s. Best fitness value: -89.688
# Generation 51 executed in 388.22 s. Best fitness value: -63.9939
# Generation 52 executed in 403.3 s. Best fitness value: -78.079
# Generation 53 executed in 447.07 s. Best fitness value: -88.9965
# Generation 54 executed in 406.42 s. Best fitness value: -98.5297
# Generation 55 executed in 450.04 s. Best fitness value: -94.0319
# Generation 56 executed in 436.98 s. Best fitness value: -71.701
# Generation 57 executed in 479.84 s. Best fitness value: -98.1292
# Generation 58 executed in 486.33 s. Best fitness value: -76.0764
# Generation 59 executed in 471.07 s. Best fitness value: -111.2738
# Generation 60 executed in 474.01 s. Best fitness value: -93.0458
# Generation 61 executed in 409.09 s. Best fitness value: -82.6653
# Generation 62 executed in 394.81 s. Best fitness value: -72.394
# Generation 63 executed in 405.23 s. Best fitness value: -73.8944
# Generation 64 executed in 408.38 s. Best fitness value: -94.8286
# Generation 65 executed in 394.97 s. Best fitness value: -86.4648
# Generation 66 executed in 405.23 s. Best fitness value: -79.134
# Generation 67 executed in 392.76 s. Best fitness value: -103.6337
# Generation 68 executed in 407.44 s. Best fitness value: -95.4952
# Generation 69 executed in 394.13 s. Best fitness value: -106.0312
# Generation 70 executed in 403.19 s. Best fitness value: -105.1923
# Generation 71 executed in 386.64 s. Best fitness value: -85.8588
# Generation 72 executed in 402.31 s. Best fitness value: -98.1894
# Generation 73 executed in 390.4 s. Best fitness value: -84.3614
# Generation 74 executed in 396.72 s. Best fitness value: -101.688
# Generation 75 executed in 371.71 s. Best fitness value: -83.2976
# Generation 76 executed in 360.31 s. Best fitness value: -106.8471
# Generation 77 executed in 375.84 s. Best fitness value: -52.1435
# Generation 78 executed in 392.76 s. Best fitness value: -116.1626
# Generation 79 executed in 378.31 s. Best fitness value: -78.0371
# Generation 80 executed in 352.59 s. Best fitness value: -91.8407
# Generation 81 executed in 370.47 s. Best fitness value: -87.0651
# Generation 82 executed in 368.34 s. Best fitness value: -105.1946
# Generation 83 executed in 357.5 s. Best fitness value: -137.2491
# Generation 84 executed in 387.89 s. Best fitness value: -153.9679
# Generation 85 executed in 402.45 s. Best fitness value: -152.3269
# Generation 86 executed in 410.84 s. Best fitness value: -156.6282
# Generation 87 executed in 392.43 s. Best fitness value: -142.4827
# Generation 88 executed in 372.73 s. Best fitness value: -163.4249
# Generation 89 executed in 402.01 s. Best fitness value: -163.3668
# Generation 90 executed in 392.32 s. Best fitness value: -135.958
# Generation 91 executed in 395.71 s. Best fitness value: -129.1555
# Generation 92 executed in 395.57 s. Best fitness value: -135.8807
# Generation 93 executed in 383.68 s. Best fitness value: -114.0863
# Generation 94 executed in 391.85 s. Best fitness value: -159.0776
# Generation 95 executed in 391.98 s. Best fitness value: -119.4345
# Generation 96 executed in 403.7 s. Best fitness value: -149.5303
# Generation 97 executed in 399.12 s. Best fitness value: -106.2531
# Generation 98 executed in 399.45 s. Best fitness value: -112.3683
# Generation 99 executed in 385.4 s. Best fitness value: -199.4771
# Generation 100 executed in 387.2 s. Best fitness value: -134.1447
# Generation 101 executed in 381.41 s. Best fitness value: -128.3774
# Generation 102 executed in 395.61 s. Best fitness value: -146.3319
# Generation 103 executed in 383.86 s. Best fitness value: -163.3511
# Generation 104 executed in 380.71 s. Best fitness value: -148.5582
# Generation 105 executed in 398.85 s. Best fitness value: -159.8921
# Generation 106 executed in 394.67 s. Best fitness value: -129.572
# Generation 107 executed in 402.71 s. Best fitness value: -153.5994
# Generation 108 executed in 395.92 s. Best fitness value: -161.8368
# Generation 109 executed in 391.48 s. Best fitness value: -134.1015
# Generation 110 executed in 393.66 s. Best fitness value: -124.5083
# Generation 111 executed in 378.89 s. Best fitness value: -168.151
# Generation 112 executed in 388.05 s. Best fitness value: -127.4164
# Generation 113 executed in 393.17 s. Best fitness value: -134.3663
# Generation 114 executed in 397.81 s. Best fitness value: -166.6468
# Generation 115 executed in 395.56 s. Best fitness value: -153.895
# Generation 116 executed in 393.21 s. Best fitness value: -112.8042
# Generation 117 executed in 392.7 s. Best fitness value: -182.6178
# Generation 118 executed in 394.13 s. Best fitness value: -164.134
# Generation 119 executed in 391.92 s. Best fitness value: -111.9498
# Generation 120 executed in 389.83 s. Best fitness value: -160.2292
# Generation 121 executed in 393.04 s. Best fitness value: -142.0816
# Generation 122 executed in 381.71 s. Best fitness value: -230.0843
# Generation 123 executed in 395.99 s. Best fitness value: -119.5539
# Generation 124 executed in 391.91 s. Best fitness value: -147.8444
# Generation 125 executed in 384.98 s. Best fitness value: -169.3853
# Generation 126 executed in 388.77 s. Best fitness value: -123.5977
# Generation 127 executed in 384.99 s. Best fitness value: -215.8754
# Generation 128 executed in 374.13 s. Best fitness value: -110.6526
# Generation 129 executed in 370.51 s. Best fitness value: -178.3851
# Generation 130 executed in 365.47 s. Best fitness value: -154.32
# Generation 131 executed in 325.38 s. Best fitness value: -175.229
# Generation 132 executed in 387.97 s. Best fitness value: -209.6651
# Generation 133 executed in 441.0 s. Best fitness value: -179.8983
# Generation 134 executed in 457.13 s. Best fitness value: -202.4479
# Generation 135 executed in 445.86 s. Best fitness value: -192.5287
# Generation 136 executed in 444.6 s. Best fitness value: -137.4291
# Generation 137 executed in 440.96 s. Best fitness value: -132.718
# Generation 138 executed in 461.27 s. Best fitness value: -123.2372
# Generation 139 executed in 456.46 s. Best fitness value: -175.682
# Generation 140 executed in 460.22 s. Best fitness value: -129.3825
# Generation 141 executed in 432.5 s. Best fitness value: -206.7486
# Generation 142 executed in 433.17 s. Best fitness value: -155.3137
# Generation 143 executed in 459.42 s. Best fitness value: -201.5394
# Generation 144 executed in 468.95 s. Best fitness value: -149.5001
# Generation 145 executed in 482.79 s. Best fitness value: -212.5145
# Generation 146 executed in 472.04 s. Best fitness value: -197.1144
# Generation 147 executed in 477.46 s. Best fitness value: -178.3677
# Generation 148 executed in 466.19 s. Best fitness value: -167.8906
# Generation 149 executed in 455.88 s. Best fitness value: -169.6254
# Generation 150 executed in 480.81 s. Best fitness value: -129.9349

# %%
# with open('best_model_AE.pickle', 'wb') as handle:
#     pickle.dump(best_model_AE, handle, protocol=pickle.HIGHEST_PROTOCOL)

# with open('fitness_values_AE.pickle', 'wb') as handle:
#     pickle.dump(fitness_values_AE, handle, protocol=pickle.HIGHEST_PROTOCOL)

# with open('best_model_AE.pickle', 'rb') as handle:
#     best_model_AE = pickle.load(handle)

# %% [markdown]
# # Test in environment

# %%
def game_evaluation(model,pretrained_weights,autoencoder,n_episodes):
    env               = gym.make("CarRacing-v2",continuous=CONTINUOUS)
    old_dict          = store_state_dict(model)
    sum_rewards       = np.zeros(n_episodes)
    for i in tqdm(range(n_episodes)):


        model       = load_state_dict(model, pretrained_weights, old_dict)
        observation = state_processer(env.reset())
        ob_tensor   = torch.cat((observation,observation,observation),dim=-1)

        done        = False
        sum_reward  = 0
        while (not done) and (sum_reward < 1000):
            action, top_patches                  = model(ob_tensor,autoencoder)
            observation_next, reward, done, info = env.step(action)
            observation_next                     = state_processer(observation_next)
            ob_tensor                            = cycle_observation(ob_tensor,observation_next)
            sum_reward                          += reward
        sum_rewards[i]=sum_reward
    return np.mean(sum_rewards), np.std(sum_rewards)

# %%
torch.set_grad_enabled(False)
lstm_hidden_dim    = 16
FEAT_EXTRACTOR     = "LOC"

model              = Agent(observation_space_size,stride,window,
                           channels,attention_out_dim,K,lstm_hidden_dim,
                           eps,CONTINUOUS,FEAT_EXTRACTOR)
autoencoder        = None
n_episodes         = 30

reward_LOC,std_LOC = game_evaluation(model,best_model_LOC,autoencoder,n_episodes)
print("LOC feature extractor.\n Mean reward : {} +- {}".format(round(reward_LOC,5),round(std_LOC,5)))
# Out:
# 100%|██████████| 30/30 [06:30<00:00, 13.02s/it]
# LOC feature extractor.
#  Mean reward : 712.67063 +- 192.44935

# %%
FEAT_EXTRACTOR       = "CONV"

model                = Agent(observation_space_size,stride,window,
                             channels,attention_out_dim,K,lstm_hidden_dim,
                             eps,CONTINUOUS,FEAT_EXTRACTOR)

autoencoder          = None
n_episodes           = 30

reward_CONV,std_CONV = game_evaluation(model,best_model_CONV,autoencoder,n_episodes)
print("CONV feature extractor.\n Mean reward : {} +- {}".format(round(reward_CONV,5),round(std_CONV,5)))
# Out:
# 100%|██████████| 30/30 [02:22<00:00,  4.75s/it]
# CONV feature extractor.
#  Mean reward : -52.05754 +- 33.37444

# %%
FEAT_EXTRACTOR  = "AE"
lstm_hidden_dim = 256

model           = Agent(observation_space_size,stride,window,
                        channels,attention_out_dim,K,lstm_hidden_dim,
                        eps,CONTINUOUS,FEAT_EXTRACTOR)

autoencoder      = Autoencoder()
autoencoder.load_state_dict(torch.load("autoencoder.pth"))
n_episodes       = 30

reward_AE,std_AE = game_evaluation(model,best_model_AE,autoencoder,n_episodes)
print("AE feature extractor.\n Mean reward : {} +- {}".format(round(reward_AE,5),round(std_AE,5)))
# Out:
# 100%|██████████| 30/30 [08:51<00:00, 17.71s/it]
# AE feature extractor.
#  Mean reward : 71.72277 +- 79.42828
